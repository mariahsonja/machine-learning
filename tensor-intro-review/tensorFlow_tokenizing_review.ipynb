# %% [markdown]
# # TensorFlow - Tokenizing Review

# %%
# importing packages
import pandas as pd

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# ## Get data

# %%
# reading and processing data 
yelp_ratings = pd.read_csv("./data/yelp_ratings.csv") #44530 samples
yelp_reviews = yelp_ratings["text"].values
yelp_reviews_labels = yelp_ratings["sentiment"].values
yelp_reviews_stars = yelp_ratings["stars"].values

# %% [markdown]
# ## Tokenize sentences

# %%
# encoding the 1000 most common words from the corpus of text
tokenizer = Tokenizer(num_words = 1000, oov_token = "<oov>")

# fitting the Tokenizer to the data - strips out punctuation and converts to lowercase
tokenizer.fit_on_texts(yelp_reviews)

# %% [markdown]
# ## View the word index

# %%
# creating a dictionary (word_index) of key/value using tokenizer - word/token pairs 
word_index = tokenizer.word_index
print(word_index)
# Out:
# {'<oov>': 1, 'the': 2, 'and': 3, 'i': 4, 'a': 5, 'to': 6, 'was': 7, 'of': 8, 'is': 9, 'for': 10, 'it': 11, 'in': 12, 'my': 13, 'with': 14, 'this': 15, 'that': 16, 'they': 17, 'we': 18, 'you': 19, 'on': 20, 'but': 21, 'have': 22, 'had': 23, 'not': 24, 'so': 25, 'are': 26, 'at': 27, 'were': 28, 'food': 29, 'place': 30, 'be': 31, 'me': 32, 'great': 33, 'as': 34, 'good': 35, 'very': 36, 'all': 37, 'there': 38, 'out': 39, 'here': 40, 'if': 41, 'service': 42, 'our': 43, 'time': 44, 'like': 45, 'get': 46, 'just': 47, 'one': 48, 'their': 49, 'from': 50, 'back': 51, 'when': 52, 'would': 53, 'up': 54, 'or': 55, 'he': 56, 'an': 57, 'will': 58, 'go': 59, "it's": 60, 'about': 61, 'she': 62, 'what': 63, 'really': 64, 'been': 65, 'your': 66, 'no': 67, 'which': 68, 'also': 69, 'can': 70, 'us': 71, 'them': 72, 'more': 73, 'only': 74, 'some': 75, 'by': 76, 'even': 77, 'because': 78, 'got': 79, 'best': 80, 'do': 81, 'well': 82, 'other': 83, "don't": 84, 'after': 85, 'nice': 86, 'has': 87, 'always': 88, 'staff': 89, 'love': 90, 'too': 91, "i've": 92, "i'm": 93, 'did': 94, 'first': 95, 'came': 96, 'never': 97, 'friendly': 98, 'her': 99, 'than': 100, 'order': 101, 'ordered': 102, 'definitely': 103, 'amazing': 104, 'chicken': 105, "didn't": 106, 'went': 107, 'come': 108, 'over': 109, 'could': 110, 'restaurant': 111, 'again': 112, 'try': 113, 'little': 114, 'delicious': 115, 'experience': 116, 'people': 117, 'made': 118, 'much': 119, 'make': 120, 'how': 121, 'who': 122, 'then': 123, '2': 124, 'going': 125, 'recommend': 126, 'know': 127, 'said': 128, 'menu': 129, '5': 130, 'day': 131, 'new': 132, 'off': 133, 'way': 134, 'two': 135, 'better': 136, 'everything': 137, 'right': 138, 'ever': 139, 'before': 140, 'any': 141, 'wait': 142, 'am': 143, 'take': 144, 'now': 145, 'pretty': 146, 'want': 147, 'his': 148, 'sure': 149, 'see': 150, 'say': 151, 'told': 152, 'took': 153, 'work': 154, 'down': 155, 'fresh': 156, 'still': 157, 'around': 158, 'few': 159, 'every': 160, '3': 161, 'vegas': 162, 'while': 163, 'night': 164, 'next': 165, 'customer': 166, 'minutes': 167, 'give': 168, 'price': 169, 'pizza': 170, 'location': 171, 'bar': 172, 'since': 173, 'asked': 174, 'eat': 175, 'think': 176, 'most': 177, 'times': 178, 'another': 179, 'many': 180, 'find': 181, 'awesome': 182, 'sauce': 183, 'cheese': 184, "can't": 185, 'table': 186, 'bad': 187, 'lunch': 188, 'being': 189, 'area': 190, 'super': 191, 'home': 192, 'small': 193, 'both': 194, 'last': 195, 'into': 196, 'long': 197, 'something': 198, 'where': 199, 'tried': 200, '4': 201, 'happy': 202, 'clean': 203, "wasn't": 204, '10': 205, 'lot': 206, 'room': 207, 'salad': 208, 'excellent': 209, 'car': 210, 'worth': 211, 'bit': 212, 'meal': 213, 'store': 214, 'need': 215, 'him': 216, 'wanted': 217, 'dinner': 218, 'looking': 219, '1': 220, 'feel': 221, 'years': 222, 'side': 223, 'done': 224, 'quality': 225, 'drinks': 226, 'though': 227, 'prices': 228, 'different': 229, 'hot': 230, 'thing': 231, 'called': 232, 'big': 233, 'found': 234, 'favorite': 235, 'check': 236, 'same': 237, 'should': 238, "you're": 239, 'enough': 240, 'away': 241, 'things': 242, 'visit': 243, 'left': 244, 'server': 245, 'hour': 246, 'these': 247, 'free': 248, 'family': 249, 'perfect': 250, 'top': 251, 'highly': 252, 'care': 253, 'drink': 254, 'coming': 255, 'stars': 256, 'nothing': 257, 'its': 258, 'friends': 259, 'breakfast': 260, 'sweet': 261, 'call': 262, 'full': 263, 'fun': 264, 'look': 265, 'atmosphere': 266, 'gave': 267, 'fries': 268, 'old': 269, 'taste': 270, 'coffee': 271, "that's": 272, 'business': 273, 'once': 274, 'burger': 275, 'job': 276, 'rice': 277, 'anything': 278, 'through': 279, 'everyone': 280, 'getting': 281, 'places': 282, 'each': 283, 'line': 284, 'sandwich': 285, 'ask': 286, 'why': 287, 'loved': 288, 'selection': 289, 'fried': 290, 'huge': 291, 'tasty': 292, 'use': 293, 'money': 294, 'manager': 295, 'meat': 296, 'house': 297, 'actually': 298, 'put': 299, 'busy': 300, 'decided': 301, 'spot': 302, 'kind': 303, 'however': 304, 'used' ...

# %% [markdown]
# ## Generate sequences

# %%
# changing sentences into vectors (sequences)
sequences = tokenizer.texts_to_sequences(yelp_reviews)

# %% [markdown]
# ## Sample text

# %%
# checking a sample
yelp_reviews[10]
# Out:
# "Wow. So surprised at the one and two star reviews!  We started with the most tender calamari. Although the marinara sauce was a bit bland, but a touch of salt made it just right. My husband had the veal with peppers and said it was so delicious and tender. The mashed potatoes were perfect. I had the salmon Diablo which was also delicious. Our salad was beautiful! Dressing was served on the salad and it was a nice amount. We ended our delicious meal with a piece of tiramisu. Our server Matt was right on!! Very pleasant and knowledgeable about the menu. Our appetizer, salad and entrees were timed perfectly. I love salad and did not mind that my entree was served while I was still eating it! No problem it let my dinner cool to just the right temp for me to eat it comfortably. \nI wonder sometimes if people just don't appreciate relaxing and taking time to eat a wonderful and beautifully prepared meal.  A wonderful atmosphere. So relaxing. The chairs are super comfortable too!!! We will certainly be back. \nGive it a try.  Don't  always go by the reviews. \nA bottle of Riesling, calamari app, two delicious entrees and dessert for $92! \nWell with it."

# %% [markdown]
# ## Text to sequence

# %%
# printing sequences
print(sequences[10])
# Out:
# [638, 25, 688, 27, 2, 48, 3, 135, 406, 345, 18, 458, 14, 2, 177, 788, 1, 536, 2, 1, 183, 7, 5, 212, 830, 21, 5, 958, 8, 974, 118, 11, 47, 138, 13, 321, 23, 2, 1, 14, 1, 3, 128, 11, 7, 25, 115, 3, 788, 2, 1, 677, 28, 250, 4, 23, 2, 730, 1, 68, 7, 69, 115, 43, 208, 7, 466, 1, 7, 407, 20, 2, 208, 3, 11, 7, 5, 86, 552, 18, 543, 43, 115, 213, 14, 5, 857, 8, 1, 43, 245, 1, 7, 138, 20, 36, 720, 3, 660, 61, 2, 129, 43, 683, 208, 3, 1, 28, 1, 537, 4, 90, 208, 3, 94, 24, 563, 16, 13, 1, 7, 407, 163, 4, 7, 157, 429, 11, 67, 465, 11, 317, 13, 218, 411, 6, 47, 2, 138, 1, 10, 32, 6, 175, 11, 1, 4, 1, 742, 41, 117, 47, 84, 1, 1, 3, 615, 44, 6, 175, 5, 354, 3, 1, 728, 213, 5, 354, 266, 25, 1, 2, 1, 26, 191, 579, 91, 18, 58, 1, 31, 51, 168, 11, 5, 113, 84, 88, 59, 76, 2, 345, 5, 1, 8, 1, 1, 1, 135, 115, 1, 3, 444, 10, 1, 82, 14, 11]

# %% [markdown]
# ## Add padding

# %%
# adding padding to create a matrix of equal-sized word vectors - padding is "pre" by default
padded = pad_sequences(sequences, padding="post")

print(padded[10])
# Out:
# [638  25 688 ...   0   0   0]

# %%
# checking shape
padded.shape
# Out:
# (44530, 1003)
